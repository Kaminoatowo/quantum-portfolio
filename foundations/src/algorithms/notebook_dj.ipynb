# %%
import numpy as np
from deutsch_jozsa import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 from deutsch_jozsa import *
#
# File c:\Users\Jacopo\Codes\quantum\quantum-portfolio\foundations\src\algorithms\deutsch_jozsa.py:2
#       1 import numpy as np
# ----> 2 from src.states.statevector import basis_state, normalize, tensor, apply_operator
#       3 from src.gates.single_qubit import H
#       5 # Define the oracle
#
# ModuleNotFoundError: No module named 'src'

# %%
# Prepare initial state

num_qubits = 1
# +1 (ancilla)
register_x = basis_state(0,num_qubits)
ancilla = basis_state(1,1)

register = normalize(tensor(ancilla, register_x))
